# %%
# Check if the python text file is exist by using (try & except statement)

try:
    f = open("python.txt")
except:
    print("Something went wrong when try to open the file")
finally:
    f.close()
# Out:
# Something went wrong when try to open the file
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e2bcd44a73b0> in <module>
#       6     print("Something went wrong when try to open the file")
#       7 finally:
# ----> 8     f.close()
#
# NameError: name 'f' is not defined

# %%
# # Solution:

# In[10]:


#The try block of code will raise an error when trying to open non-existed python text file:
